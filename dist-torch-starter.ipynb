# %%
import os, sys
import cdsw

# %%
NUM_WORKERS = 2
CMD = '''mpirun -np {} -H {} -bind-to none -map-by slot \
-mca pml ob1 -mca btl ^openib -mca plm_rsh_args '-p 2222 -o StrictHostKeyChecking=no' -mca btl_tcp_if_include eth0 \
-x NCCL_SOCKET_IFNAME=eth0 -x COLUMNS -x LINES \
python3 dist-torch-hvd.py'''

workers = cdsw.launch_workers(n=NUM_WORKERS, cpu=1, memory=4, nvidia_gpu=0,
                              code="import time; time.sleep(365*24*3600)")
print('Starting workers ...')
worker_ids = [worker["id"] for worker in workers]
running_workers = cdsw.await_workers(worker_ids,
                              wait_for_completion=False,
                              timeout_seconds=120)
worker_ips = [worker["ip_address"] for worker in \
                              running_workers["workers"]]
print('Workers:', worker_ips)

if len(running_workers) == NUM_WORKERS:
    hosts_str = ",".join([worker_ip+":1" for worker_ip in worker_ips])
    cmd = CMD.format(len(worker_ips), hosts_str)
    cmd = "horovodrun -np {} -H {} -p 2222 python3 dist-torch-hvd.py 2>&1".format(
                                  len(worker_ips),
                                  hosts_str)
    print('Preparing to run: ' + cmd)
    os.system(cmd)
    print('DONE')
    #cdsw.stop_workers()
else:
    print('Errors when starting workers. Exits.')
    sys.exit(1)
# Out:
# Starting workers ...
# Workers: ['100.100.7.177', '100.100.7.183']
# Preparing to run: horovodrun -np 2 -H 100.100.7.177:1,100.100.7.183:1 -p 2222 python3 dist-torch-hvd.py 2>&1
# DONE

# %%
cdsw.list_workers()
# Out:
# [{'id': 'b49kyjsauudysw8p',
#   'name': 'Untitled Worker',
#   'project': {'id': 57,
#    'name': 'Distributed PyTorch with Horovod',
#    'slug': 'pauldefusco/distributed-pytorch-with-horovod',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco/distributed-pytorch-with-horovod',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/projects/pauldefusco/distributed-pytorch-with-horovod',
#    'default_engine_type': 'ml_runtime'},
#   'owner': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco',
#    'is_team': False},
#   'creator': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco'},
#   'biller': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco'},
#   'status': 'running',
#   'oomKilled': False,
#   'cluster_id': 1,
#   'batch': True,
#   'created_at': '2022-05-24T01:52:48.869Z',
#   'scheduling_at': '2022-05-24T01:52:48.869Z',
#   'starting_at': '2022-05-24T01:53:04.048Z',
#   'running_at': '2022-05-24T01:53:04.646Z',
#   'stopping_at': None,
#   'finished_at': None,
#   'deleted': False,
#   'exit_code': None,
#   'k8s': {'reason': None,
#    'message': None,
#    'internal_error_code': None,
#    'exit_code': None},
#   'master_id': 'wum6w72c75l0qcz7',
#   'job_id': None,
#   'batch_run_id': None,
#   'workers': 0,
#   'engine_image': {'id': None,
#    'tag': None,
#    'repository': None,
#    'description': None},
#   'runtime': {'id': 144,
#    'description': 'Python 3.8 JupyterLab Distributed PyTorch with GPU',
#    'image_identifier': 'zelkey/cml-dist-torch:1.0-cuda11.1',
#    'editor': 'JupyterLab',
#    'kernel': 'Python 3.8'},
#   'kernel': None,
#   'cpu': 1,
#   'memory': 4,
#   'nvidia_gpu': 0,
#   'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/projects/pauldefusco/distributed-pytorch-with-horovod/dashboards/b49kyjsauudysw8p',
#   'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco/distributed-pytorch-with-horovod/engines/b49kyjsauudysw8p',
#   'assets_cdn_root': 'https://consoles.ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/0/57/b49kyjsauudysw8p/',
#   'app_url': 'https://b49kyjsauudysw8p.ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/',
#   'share_token': None,
#   'shared_view_visibility': 'private',
#   'cost': 0.002179391666666667,
#   'duration': 38,
#   'adhoc': False,
#   'ip_address': '100.100.7.177'},
#  {'id': 'oqrhrmrq355w5caq',
#   'name': 'Untitled Worker',
#   'project': {'id': 57,
#    'name': 'Distributed PyTorch with Horovod',
#    'slug': 'pauldefusco/distributed-pytorch-with-horovod',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco/distributed-pytorch-with-horovod',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/projects/pauldefusco/distributed-pytorch-with-horovod',
#    'default_engine_type': 'ml_runtime'},
#   'owner': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco',
#    'is_team': False},
#   'creator': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco'},
#   'biller': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco'},
#   'status': 'running',
#   'oomKilled': False,
#   'cluster_id': 1,
#   'batch': True,
#   'created_at': '2022-05-24T01:52:48.863Z',
#   'scheduling_at': '2022-05-24T01:52:48.863Z',
#   'starting_at': '2022-05-24T01:53:02.062Z',
#   'running_at': '2022-05-24T01:53:02.344Z',
#   'stopping_at': None,
#   'finished_at': None,
#   'deleted': False,
#   'exit_code': None,
#   'k8s': {'reason': None,
#    'message': None,
#    'internal_error_code': None,
#    'exit_code': None},
#   'master_id': 'wum6w72c75l0qcz7',
#   'job_id': None,
#   'batch_run_id': None,
#   'workers': 0,
#   'engine_image': {'id': None,
#    'tag': None,
#    'repository': None,
#    'description': None},
#   'runtime': {'id': 144,
#    'description': 'Python 3.8 JupyterLab Distributed PyTorch with GPU',
#    'image_identifier': 'zelkey/cml-dist-torch:1.0-cuda11.1',
#    'editor': 'JupyterLab',
#    'kernel': 'Python 3.8'},
#   'kernel': None,
#   'cpu': 1,
#   'memory': 4,
#   'nvidia_gpu': 0,
#   'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/projects/pauldefusco/distributed-pytorch-with-horovod/dashboards/oqrhrmrq355w5caq',
#   'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco/distributed-pytorch-with-horovod/engines/oqrhrmrq355w5caq',
#   'assets_cdn_root': 'https://consoles.ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/0/57/oqrhrmrq355w5caq/',
#   'app_url': 'https://oqrhrmrq355w5caq.ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/',
#   'share_token': None,
#   'shared_view_visibility': 'private',
#   'cost': 0.0023136750000000003,
#   'duration': 40,
#   'adhoc': False,
#   'ip_address': '100.100.7.183'},
#  {'id': 'ouhhypsdty0x6i9u',
#   'name': 'Untitled Worker',
#   'project': {'id': 57,
#    'name': 'Distributed PyTorch with Horovod',
#    'slug': 'pauldefusco/distributed-pytorch-with-horovod',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco/distributed-pytorch-with-horovod',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/projects/pauldefusco/distributed-pytorch-with-horovod',
#    'default_engine_type': 'ml_runtime'},
#   'owner': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco',
#    'is_team': False},
#   'creator': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco'},
#   'biller': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco'},
#   'status': 'failed',
#   'oomKilled': False,
#   'cluster_id': 1,
#   'batch': True,
#   'created_at': '2022-05-24T01:50:52.991Z',
#   'scheduling_at': '2022-05-24T01:50:52.991Z',
#   'starting_at': '2022-05-24T01:51:06.427Z',
#   'running_at': '2022-05-24T01:51:07.074Z',
#   'stopping_at': '2022-05-24T01:51:14.485Z',
#   'finished_at': '2022-05-24T01:51:17.095Z',
#   'deleted': False,
#   'exit_code': 137,
#   'k8s': {'reason': 'Error',
#    'message': '',
#    'internal_error_code': 0,
#    'exit_code': 137},
#   'master_id': 'wum6w72c75l0qcz7',
#   'job_id': None,
#   'batch_run_id': None,
#   'workers': 0,
#   'engine_image': {'id': None,
#    'tag': None,
#    'repository': None,
#    'description': None},
#   'runtime': {'id': 144,
#    'description': 'Python 3.8 JupyterLab Distributed PyTorch with GPU',
#    'image_identifier': 'zelkey/cml-dist-torch:1.0-cuda11.1',
#    'editor': 'JupyterLab',
#    'kernel': 'Python 3.8'},
#   'kernel': None,
#   'cpu': 1,
#   'memory': 4,
#   'nvidia_gpu': 0,
#   'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/projects/pauldefusco/distributed-pytorch-with-horovod/dashboards/ouhhypsdty0x6i9u',
#   'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco/distributed-pytorch-with-horovod/engines/ouhhypsdty0x6i9u',
#   'assets_cdn_root': 'https://consoles.ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/0/57/ouhhypsdty0x6i9u/',
#   'app_url': 'https://ouhhypsdty0x6i9u.ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/',
#   'share_token': None,
#   'shared_view_visibility': 'private',
#   'cost': 0.01,
#   'duration': 8,
#   'adhoc': False,
#   'ip_address': 'unknown'},
#  {'id': 'ey4ryukf3rndujas',
#   'name': 'Untitled Worker',
#   'project': {'id': 57,
#    'name': 'Distributed PyTorch with Horovod',
#    'slug': 'pauldefusco/distributed-pytorch-with-horovod',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco/distributed-pytorch-with-horovod',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/projects/pauldefusco/distributed-pytorch-with-horovod',
#    'default_engine_type': 'ml_runtime'},
#   'owner': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco',
#    'is_team': False},
#   'creator': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco'},
#   'biller': {'id': 4,
#    'username': 'pauldefusco',
#    'name': 'Paul de Fusco',
#    'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco',
#    'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/users/pauldefusco'},
#   'status': 'failed',
#   'oomKilled': False,
#   'cluster_id': 1,
#   'batch': True,
#   'created_at': '2022-05-24T01:50:52.978Z',
#   'scheduling_at': '2022-05-24T01:50:52.978Z',
#   'starting_at': '2022-05-24T01:51:04.426Z',
#   'running_at': '2022-05-24T01:51:05.010Z',
#   'stopping_at': '2022-05-24T01:51:14.484Z',
#   'finished_at': '2022-05-24T01:51:16.318Z',
#   'deleted': False,
#   'exit_code': -1,
#   'k8s': {'reason': '',
#    'message': '',
#    'internal_error_code': 0,
#    'exit_code': -1},
#   'master_id': 'wum6w72c75l0qcz7',
#   'job_id': None,
#   'batch_run_id': None,
#   'workers': 0,
#   'engine_image': {'id': None,
#    'tag': None,
#    'repository': None,
#    'description': None},
#   'runtime': {'id': 144,
#    'description': 'Python 3.8 JupyterLab Distributed PyTorch with GPU',
#    'image_identifier': 'zelkey/cml-dist-torch:1.0-cuda11.1',
#    'editor': 'JupyterLab',
#    'kernel': 'Python 3.8'},
#   'kernel': None,
#   'cpu': 1,
#   'memory': 4,
#   'nvidia_gpu': 0,
#   'url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/api/v1/projects/pauldefusco/distributed-pytorch-with-horovod/dashboards/ey4ryukf3rndujas',
#   'html_url': 'https://ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/pauldefusco/distributed-pytorch-with-horovod/engines/ey4ryukf3rndujas',
#   'assets_cdn_root': 'https://consoles.ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/0/57/ey4ryukf3rndujas/',
#   'app_url': 'https://ey4ryukf3rndujas.ml-4d51f976-b26.go02-dem.ylcu-atmi.cloudera.site/',
#   'share_token': None,
#   'shared_view_visibility': 'private',
#   'cost': 0.01,
#   'duration': 10,
#   'adhoc': False,
#   'ip_address': 'unknown'}]

# %% [markdown]
# With horovod timeline

# %%
NUM_WORKERS = 2
CMD = '''mpirun -np {} -H {} -bind-to none -map-by slot \
-mca pml ob1 -mca btl ^openib -mca plm_rsh_args '-p 2222 -o StrictHostKeyChecking=no' -mca btl_tcp_if_include eth0 \
-x NCCL_SOCKET_IFNAME=eth0 -x COLUMNS -x LINES \
python3 dist-torch-hvd.py'''

workers = cdsw.launch_workers(n=NUM_WORKERS, cpu=1, memory=4, nvidia_gpu=1,
                              code="import time; time.sleep(365*24*3600)")
print('Starting workers ...')
worker_ids = [worker["id"] for worker in workers]
running_workers = cdsw.await_workers(worker_ids,
                              wait_for_completion=False,
                              timeout_seconds=120)
worker_ips = [worker["ip_address"] for worker in \
                              running_workers["workers"]]
print('Workers:', worker_ips)

if len(running_workers) == NUM_WORKERS:
    hosts_str = ",".join([worker_ip+":1" for worker_ip in worker_ips])
    cmd = CMD.format(len(worker_ips), hosts_str)
    cmd = "horovodrun -np {} --timeline-filename timeline.json -H {} -p 2222 python3 dist-torch-hvd.py 2>&1".format(
                                  len(worker_ips),
                                  hosts_str)
    print('Preparing to run: ' + cmd)
    os.system(cmd)
    print('DONE')
    cdsw.stop_workers()
else:
    print('Errors when starting workers. Exits.')
    sys.exit(1)
# Out:
# Starting workers ...
# Workers: []
# Preparing to run: horovodrun -np 0 --timeline-filename timeline.json -H  -p 2222 python3 dist-torch-hvd.py 2>&1
# DONE
